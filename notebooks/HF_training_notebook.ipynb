# %%
import datasets
from datasets import load_dataset, ClassLabel
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from transformers import DistilBertForSequenceClassification, Trainer, TrainingArguments
from transformers import pipeline
import evaluate

import numpy as np
import pandas as pd

# %%
# pip install transformers datasets accelerate evaluate scikit-learn

# %%
df = pd.read_csv("train_sections_data.csv", encoding_errors='ignore')

# %%
df = df.iloc[:, 0:10]

# %%
df
# Out:
#                                                     Text  IsBold  IsItalic  \
# 0      NOTES TO THE ACCOUNTS FOR THE 52 WEEK PERIOD E...    True     False
# 1                                 DERIVATIVE INSTRUMENTS   False     False
# 2                                                     -6   False     False
# 3      The following performance graph and related in...   False     False
# 4      Typical service offerings include supply chain...   False     False
# ...                                                  ...     ...       ...
# 14210  The scheme's assets comprise a Friends Provide...   False     False
# 14211                   Transaction and Litigation Costs   False      True
# 14212  The weighted-average fair value of options gra...   False     False
# 14213  The analysis of gross contractual cash flow di...   False     False
# 14214  the cost of lab supplies and acquiring, develo...   False     False
#
#        IsUnderlined   Left  Right    Top  Bottom         FontType  Label
# 0             False   49.5  544.0   67.3    96.1  New Times Roman      1
# 1             False   41.5  140.2   49.0    54.7  New Times Roman      1
# 2             False  113.5  122.2  409.3   414.9  New Times Roman      0
# 3             False  112.9  706.9  339.0   360.3  New Times Roman      0
# 4             False   33.1  808.5  328.2   369.9  New Times Roman      0
# ...             ...    ...    ...    ...     ...              ...    ...
# 14210         False   36.6  553.1  575.5   594.9  New Times Roman      0
# 14211          True   42.7  151.4   91.0    96.7  New Times Roman      1
# 14212         False   33.1  806.9  106.1   121.3  New Times Roman      0
# 14213         False   42.6  553.1  667.0   687.0  New Times Roman      0
# 14214         False  170.0  546.2  337.8   343.5  New Times Roman      0
#
# [14215 rows x 10 columns]

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['Text']

# %%
df = df.dropna()

# %%
df
# Out:
#                                                     Text  IsBold  IsItalic  \
# 0      NOTES TO THE ACCOUNTS FOR THE 52 WEEK PERIOD E...    True     False
# 1                                 DERIVATIVE INSTRUMENTS   False     False
# 2                                                     -6   False     False
# 3      The following performance graph and related in...   False     False
# 4      Typical service offerings include supply chain...   False     False
# ...                                                  ...     ...       ...
# 14210  The scheme's assets comprise a Friends Provide...   False     False
# 14211                   Transaction and Litigation Costs   False      True
# 14212  The weighted-average fair value of options gra...   False     False
# 14213  The analysis of gross contractual cash flow di...   False     False
# 14214  the cost of lab supplies and acquiring, develo...   False     False
#
#        IsUnderlined   Left  Right    Top  Bottom         FontType  Label
# 0             False   49.5  544.0   67.3    96.1  New Times Roman      1
# 1             False   41.5  140.2   49.0    54.7  New Times Roman      1
# 2             False  113.5  122.2  409.3   414.9  New Times Roman      0
# 3             False  112.9  706.9  339.0   360.3  New Times Roman      0
# 4             False   33.1  808.5  328.2   369.9  New Times Roman      0
# ...             ...    ...    ...    ...     ...              ...    ...
# 14210         False   36.6  553.1  575.5   594.9  New Times Roman      0
# 14211          True   42.7  151.4   91.0    96.7  New Times Roman      1
# 14212         False   33.1  806.9  106.1   121.3  New Times Roman      0
# 14213         False   42.6  553.1  667.0   687.0  New Times Roman      0
# 14214         False  170.0  546.2  337.8   343.5  New Times Roman      0
#
# [13583 rows x 10 columns]

# %%
df['FontType'].unique()
# Out:
# array(['New Times Roman'], dtype=object)

# %%
from sklearn.utils import resample

df_majority = df[df.Label==0]
df_minority = df[df.Label==1]


df_minority_upsampled = resample(df_minority,
                                 replace=True,
                                 n_samples=len(df_majority),
                                 random_state=42)


df_upsampled = pd.concat([df_majority, df_minority_upsampled])


df_upsampled.Label.value_counts()
# Out:
# 0    9888
# 1    9888
# Name: Label, dtype: int64

# %%
df = df_upsampled

# %%
df['updatedText'] = ''

# %%
df
# Out:
#                                                    Text  IsBold  IsItalic  \
# 2                                                    -6   False     False
# 3     The following performance graph and related in...   False     False
# 4     Typical service offerings include supply chain...   False     False
# 5     A substantial portion of contract and administ...   False     False
# 6     PMA applications must be supported by valid sc...   False     False
# ...                                                 ...     ...       ...
# 6816                                           Overview    True     False
# 5362                                       OTHER ASSETS    True     False
# 6614                                      Consolidation    True     False
# 4655                                  Long-lived Assets   False     False
# 1332                                            Item 9.    True     False
#
#       IsUnderlined   Left  Right    Top  Bottom         FontType  Label  \
# 2            False  113.5  122.2  409.3   414.9  New Times Roman      0
# 3            False  112.9  706.9  339.0   360.3  New Times Roman      0
# 4            False   33.1  808.5  328.2   369.9  New Times Roman      0
# 5            False   33.1  808.6  165.5   189.2  New Times Roman      0
# 6            False  112.4  724.9  261.4   336.2  New Times Roman      0
# ...            ...    ...    ...    ...     ...              ...    ...
# 6816         False  112.9  144.0  300.7   306.2  New Times Roman      1
# 5362         False  105.0  179.4  547.1   553.9  New Times Roman      1
# 6614         False   33.1   78.4  322.3   327.8  New Times Roman      1
# 4655         False   34.3   93.2  366.0   371.7  New Times Roman      1
# 1332         False   34.3   56.7  200.5   206.0  New Times Roman      1
#
#      updatedText
# 2
# 3
# 4
# 5
# 6
# ...          ...
# 6816
# 5362
# 6614
# 4655
# 1332
#
# [19776 rows x 11 columns]

# %%
bold_titel, bold_text = [], []
italic_titel, italic_text = [], []
underlined_titel, underlined_text = [], []

for i, row in df.iterrows():
    text = row['Text']
    if row['IsBold']:
        text += ' bold'
    if row['IsItalic']:
        text += ' italic'
    if row['IsUnderlined']:
        text += ' underlined'

    df.loc[i, 'updatedText'] = text

    if row['IsBold'] and row['Label']:
        bold_titel.append(i)
    elif row['IsBold'] and not row['Label']:
        bold_text.append(i)

    if row['IsItalic'] and row['Label']:
        italic_titel.append(i)
    elif row['IsItalic'] and not row['Label']:
        italic_text.append(i)

    if row['IsUnderlined'] and row['Label']:
        underlined_titel.append(i)
    elif row['IsUnderlined'] and not row['Label']:
        underlined_text.append(i)

# %%
print(len(bold_titel), len(bold_text))
print(len(italic_titel), len(italic_text))
print(len(underlined_titel), len(underlined_text))
# Out:
# 8347 219
# 2251 215
# 306 11

# %%
df.iloc[13579]['updatedText']
# Out:
# 'ANNUAL REPORT bold'

# %%
dataset = datasets.Dataset.from_pandas(df)

# %%
dataset.features
# Out:
# {'Text': Value(dtype='string', id=None),
#  'IsBold': Value(dtype='bool', id=None),
#  'IsItalic': Value(dtype='bool', id=None),
#  'IsUnderlined': Value(dtype='bool', id=None),
#  'Left': Value(dtype='float64', id=None),
#  'Right': Value(dtype='float64', id=None),
#  'Top': Value(dtype='float64', id=None),
#  'Bottom': Value(dtype='float64', id=None),
#  'FontType': Value(dtype='string', id=None),
#  'Label': Value(dtype='int64', id=None),
#  'updatedText': Value(dtype='string', id=None),
#  '__index_level_0__': Value(dtype='int64', id=None)}

# %%
title_class = ClassLabel(num_classes = 2)

# %%
dataset = dataset.cast_column("Label", title_class)
# Out:
# Casting the dataset:   0%|          | 0/19776 [00:00<?, ? examples/s]

# %%
dataset = dataset.rename_column("Label", "label")

# %%
dataset.features
# Out:
# {'Text': Value(dtype='string', id=None),
#  'IsBold': Value(dtype='bool', id=None),
#  'IsItalic': Value(dtype='bool', id=None),
#  'IsUnderlined': Value(dtype='bool', id=None),
#  'Left': Value(dtype='float64', id=None),
#  'Right': Value(dtype='float64', id=None),
#  'Top': Value(dtype='float64', id=None),
#  'Bottom': Value(dtype='float64', id=None),
#  'FontType': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['0', '1'], id=None),
#  'updatedText': Value(dtype='string', id=None),
#  '__index_level_0__': Value(dtype='int64', id=None)}

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def tokenize_function(examples):
    return tokenizer(examples["updatedText"], padding="max_length", truncation=True)

# %%
tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/19776 [00:00<?, ? examples/s]

# %%
tokenized_datasets
# Out:
# Dataset({
#     features: ['Text', 'IsBold', 'IsItalic', 'IsUnderlined', 'Left', 'Right', 'Top', 'Bottom', 'FontType', 'label', 'updatedText', '__index_level_0__', 'input_ids', 'attention_mask'],
#     num_rows: 19776
# })

# %%
train_valid = tokenized_datasets.train_test_split(test_size=0.2, shuffle=True, stratify_by_column="label")

# %%
train_valid
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Text', 'IsBold', 'IsItalic', 'IsUnderlined', 'Left', 'Right', 'Top', 'Bottom', 'FontType', 'label', 'updatedText', '__index_level_0__', 'input_ids', 'attention_mask'],
#         num_rows: 15820
#     })
#     test: Dataset({
#         features: ['Text', 'IsBold', 'IsItalic', 'IsUnderlined', 'Left', 'Right', 'Top', 'Bottom', 'FontType', 'label', 'updatedText', '__index_level_0__', 'input_ids', 'attention_mask'],
#         num_rows: 3956
#     })
# })

# %%
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=2)
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'pre_classifier.weight', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
accuracy = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# %%
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=5,              # total number of training epochs
    per_device_train_batch_size=32,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=300,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    logging_steps=10,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
)

# %%
trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    tokenizer=tokenizer,
    train_dataset=train_valid['train'],         # training dataset
    eval_dataset=train_valid['test'],             # evaluation dataset
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='2475' max='2475' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2475/2475 1:07:10, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.076100</td>
#       <td>0.093216</td>
#       <td>0.971183</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.077000</td>
#       <td>0.062024</td>
#       <td>0.979272</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.061600</td>
#       <td>0.054022</td>
#       <td>0.984580</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.043900</td>
#       <td>0.064816</td>
#       <td>0.983064</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.048600</td>
#       <td>0.067861</td>
#       <td>0.983316</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2475, training_loss=0.0673183066458112, metrics={'train_runtime': 4035.4714, 'train_samples_per_second': 19.601, 'train_steps_per_second': 0.613, 'total_flos': 1.04781712336896e+16, 'train_loss': 0.0673183066458112, 'epoch': 5.0})

# %%
df_test = pd.read_csv("test_sections_data.csv", encoding_errors='ignore')

# %%
df_test
# Out:
#                                                    Text  IsBold  IsItalic  \
# 0                                  Employee Involvement    True     False
# 1                                          Income Taxes    True      True
# 2                                                   NaN   False     False
# 3                    the Audit & Remuneration Committee   False      True
# 4                                     Industry Overview    True     False
# ...                                                 ...     ...       ...
# 1574  The retail apparel industry is highly competit...   False     False
# 1575  Gary Barrett joined AngioDynamics in May 2014 ...   False     False
# 1576  Each of our products is offered to customers o...   False     False
# 1577  Includes corporate debt instruments (74%), mor...   False     False
# 1578  New Accounting Standards or Updates Recently A...   False     False
#
#       IsUnderlined   Left  Right    Top  Bottom         FontType  Label
# 0            False   77.9  175.6  425.3   434.2  New Times Roman      1
# 1            False   33.1   79.6  284.8   290.6  New Times Roman      1
# 2            False   77.9   81.3  346.1   355.0  New Times Roman      0
# 3            False  124.8  247.3  380.3   385.9  New Times Roman      0
# 4            False   33.1   93.5  266.5   272.0  New Times Roman      1
# ...            ...    ...    ...    ...     ...              ...    ...
# 1574         False   33.1  808.5   68.3   109.9  New Times Roman      0
# 1575         False   33.1  803.7  262.8   286.4  New Times Roman      0
# 1576         False   33.1  770.1  184.1   199.4  New Times Roman      0
# 1577         False  128.5  728.7  242.4   257.6  New Times Roman      0
# 1578         False   34.3  220.8  241.2   246.8  New Times Roman      1
#
# [1579 rows x 10 columns]

# %%
df_test.columns[df_test.isna().any()].tolist()
# Out:
# ['Text']

# %%
df_test = df_test.dropna()

# %%
df_test
# Out:
#                                                    Text  IsBold  IsItalic  \
# 0                                  Employee Involvement    True     False
# 1                                          Income Taxes    True      True
# 3                    the Audit & Remuneration Committee   False      True
# 4                                     Industry Overview    True     False
# 5                                       Lonza Agreement    True      True
# ...                                                 ...     ...       ...
# 1574  The retail apparel industry is highly competit...   False     False
# 1575  Gary Barrett joined AngioDynamics in May 2014 ...   False     False
# 1576  Each of our products is offered to customers o...   False     False
# 1577  Includes corporate debt instruments (74%), mor...   False     False
# 1578  New Accounting Standards or Updates Recently A...   False     False
#
#       IsUnderlined   Left  Right    Top  Bottom         FontType  Label
# 0            False   77.9  175.6  425.3   434.2  New Times Roman      1
# 1            False   33.1   79.6  284.8   290.6  New Times Roman      1
# 3            False  124.8  247.3  380.3   385.9  New Times Roman      0
# 4            False   33.1   93.5  266.5   272.0  New Times Roman      1
# 5            False  112.4  169.8  307.3   313.1  New Times Roman      1
# ...            ...    ...    ...    ...     ...              ...    ...
# 1574         False   33.1  808.5   68.3   109.9  New Times Roman      0
# 1575         False   33.1  803.7  262.8   286.4  New Times Roman      0
# 1576         False   33.1  770.1  184.1   199.4  New Times Roman      0
# 1577         False  128.5  728.7  242.4   257.6  New Times Roman      0
# 1578         False   34.3  220.8  241.2   246.8  New Times Roman      1
#
# [1496 rows x 10 columns]

# %%
df_test['FontType'].unique()
# Out:
# array(['New Times Roman'], dtype=object)

# %%
df_test['updatedText'] = ''
# Out:
# <ipython-input-46-35061461d158>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['updatedText'] = ''

# %%
bold_titel, bold_text = [], []
italic_titel, italic_text = [], []
underlined_titel, underlined_text = [], []

for i, row in df_test.iterrows():
    text = row['Text']
    if row['IsBold']:
        text += ' bold'
    if row['IsItalic']:
        text += ' italic'
    if row['IsUnderlined']:
        text += ' underlined'

    df_test.loc[i, 'updatedText'] = text

    if row['IsBold'] and row['Label']:
        bold_titel.append(i)
    elif row['IsBold'] and not row['Label']:
        bold_text.append(i)

    if row['IsItalic'] and row['Label']:
        italic_titel.append(i)
    elif row['IsItalic'] and not row['Label']:
        italic_text.append(i)

    if row['IsUnderlined'] and row['Label']:
        underlined_titel.append(i)
    elif row['IsUnderlined'] and not row['Label']:
        underlined_text.append(i)

# %%
print(len(bold_titel), len(bold_text))
print(len(italic_titel), len(italic_text))
print(len(underlined_titel), len(underlined_text))
# Out:
# 350 19
# 113 21
# 17 2

# %%
test_dataset = datasets.Dataset.from_pandas(df_test)

# %%
test_dataset
# Out:
# Dataset({
#     features: ['Text', 'IsBold', 'IsItalic', 'IsUnderlined', 'Left', 'Right', 'Top', 'Bottom', 'FontType', 'Label', 'updatedText', '__index_level_0__'],
#     num_rows: 1496
# })

# %%
title_class = ClassLabel(num_classes = 2)
test_dataset = test_dataset.cast_column("Label", title_class)
# Out:
# Casting the dataset:   0%|          | 0/1496 [00:00<?, ? examples/s]

# %%
test_dataset = test_dataset.rename_column("Label", "label")

# %%
test_tokenized_datasets = test_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/1496 [00:00<?, ? examples/s]

# %%
test_tokenized_datasets
# Out:
# Dataset({
#     features: ['Text', 'IsBold', 'IsItalic', 'IsUnderlined', 'Left', 'Right', 'Top', 'Bottom', 'FontType', 'label', 'updatedText', '__index_level_0__', 'input_ids', 'attention_mask'],
#     num_rows: 1496
# })

# %%
model.eval()
# Out:
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
trainer.predict(test_tokenized_datasets)
# Out:
# PredictionOutput(predictions=array([[-3.0535157 ,  2.9586034 ],
#        [-3.249946  ,  3.2051532 ],
#        [ 1.1665748 , -0.99915504],
#        ...,
#        [ 4.6252027 , -3.8159842 ],
#        [ 4.5212407 , -3.8145194 ],
#        [ 1.0959167 , -0.9361274 ]], dtype=float32), label_ids=array([1, 1, 0, ..., 0, 0, 1]), metrics={'test_loss': 0.088981993496418, 'test_accuracy': 0.9725935828877005, 'test_runtime': 25.9455, 'test_samples_per_second': 57.659, 'test_steps_per_second': 0.925})

# %%
pipe = pipeline(task= 'sentiment-analysis', model="/content/results/checkpoint-1700")

# %%
pipe

# %%
output = pipe("Employee Involvement bold")

# %%
output
# Out:
# [{'label': 'LABEL_1', 'score': 0.9976553916931152}]
